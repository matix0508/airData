# %%
from handler import App

# %%
app = App()

# %%
app.run()

# %%
app.data
# Out:
# Set of data from 83 days

# %%
output = {}
for key in app.data.days[1].make_dict().keys():
    output[key] = []
    for d in app.data.days:
        if key in d.make_dict().keys():
            output[key] += list(d.make_dict()[key])
print(output)
# Out:
# {'PM1': [7.66, 11.93, 12.0, 13.9, 14.07, 9.28, 6.06, 6.38, 5.65, 6.43, 9.1, 6.53, 8.62, 8.58, 11.85, 12.87, 13.54, 13.69, 14.2, 14.84, 15.93, 15.64, 13.74, 15.13, 60.94, 60.91, 59.14, 59.12, 56.97, 54.6, 52.73, 51.77, 50.95, 49.52, 44.1, 28.84, 15.98, 13.68, 12.98, 11.43, 12.55, 13.24, 14.26, 19.06, 32.44, 46.49, 52.94, 52.92, 68.88, 52.87, 19.21, 18.77, 16.01, 14.93, 15.55, 14.91, 14.59, 14.45, 13.45, 13.04, 11.94, 11.08, 10.66, 10.49, 11.01, 11.46, 8.85, 7.6, 7.02, 5.76, 5.85, 4.47, 6.93, 5.56, 5.28, 4.65, 3.9, 3.67, 3.92, 4.17, 4.86, 4.81, 6.27, 7.22, 7.55, 4.34, 4.07, 3.72, 4.19, 6.04, 5.81, 10.08, 12.68, 10.01, 10.09, 9.3, 23.79, 22.32, 20.51, 19.42, 17.28, 16.71, 17.19, 18.19, 17.13, 16.92, 17.34, 17.77, 17.0, 16.21, 15.87, 18.02, 18.2, 16.7, 13.99, 15.38, 14.95, 16.7, 16.79, 17.17, 19.38, 21.7, 21.1, 18.51, 15.41, 13.64, 11.98, 11.79, 13.01, 13.69, 11.79, 8.99, 10.1, 10.15, 11.22, 10.72, 13.09, 16.73, 15.67, 18.1, 19.01, 22.66, 34.8, 44.93, 13.61, 13.2, 13.05, 13.02, 10.14, 8.
# ...
